# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
SCRIPT_DIR = os.path.dirname(os.path.abspath(os.getcwd()))
sys.path.append(SCRIPT_DIR)

from bocpd import bocpd
from hazard import ConstantHazard
from models import DSMGaussian, Gaussian
from omega_estimator import OmegaEstimatorGaussian
from utils.find_cp import find_cp

df = pd.read_csv("SPY.txt",header=None)
df.columns = ["datetime","open","high","low","close","volume"]
df["datetime"] = pd.to_datetime(df["datetime"])
df.set_index("datetime",inplace=True)
df = df.asfreq("1T")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Daniele\anaconda3\envs\develop-env\lib\site-packages\jax\_src\lib\__init__.py in <module>
#      36 try:
# ---> 37   import jaxlib
#      38 except ModuleNotFoundError as err:
#
# ModuleNotFoundError: No module named 'jaxlib'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12436/108792024.py in <module>
#      10 from hazard import ConstantHazard
#      11 from models import DSMGaussian, Gaussian
# ---> 12 from omega_estimator import OmegaEstimatorGaussian
#      13 from utils.find_cp import find_cp
#      14
#
# c:\Users\Daniele\OneDrive\Desktop\ChangePointDetection\DSM-bocd\omega_estimator.py in <module>
#       1 import numpy as np
#       2
# ----> 3 import jax
#       4 import jax.numpy as jnp
#       5 from tensorflow_probability.substrates import jax as tfp
#
# c:\Users\Daniele\anaconda3\envs\develop-env\lib\site-packages\jax\__init__.py in <module>
#      35 # We want the exported object to be the class, so we first import the module
#      36 # to make sure a later import doesn't overwrite the class.
# ---> 37 from . import config as _config_module
#      38 del _config_module
#      39
#
# c:\Users\Daniele\anaconda3\envs\develop-env\lib\site-packages\jax\config.py in <module>
#      16
#      17 # flake8: noqa: F401
# ---> 18 from jax._src.config import config
#
# c:\Users\Daniele\anaconda3\envs\develop-env\lib\site-packages\jax\_src\config.py in <module>
#      25 import warnings
#      26
# ---> 27 from jax._src import lib
#      28 from jax._src.lib import jax_jit
#      29
#
# c:\Users\Daniele\anaconda3\envs\develop-env\lib\site-packages\jax\_src\lib\__init__.py in <module>
#      37   import jaxlib
#      38 except ModuleNotFoundError as err:
# ---> 39   raise ModuleNotFoundError(
#      40     'jax requires jaxlib to be installed. See '
#      41     'https://github.com/google/jax#installation for installation instructions.'
#
# ModuleNotFoundError: jax requires jaxlib to be installed. See https://github.com/google/jax#installation for installation instructions.

# %%
df.loc["2019-12-31 06:00":,"close"].plot(figsize=(12.8,7.20))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
def m(x):
    return np.asarray([(1+x**2)**(-1/2)])

def grad_m(x):
    return np.asarray([[-x/((1+x**2)**(3/2))]])


mean_mu0 = 0
var_mu0 = 1

mean_Sigma0 = 10
var_Sigma0 = 1

mu0 = np.array([[mean_mu0/var_mu0], [1/var_mu0]])

Sigma0 = np.eye(2)
Sigma0[0, 0] = mean_Sigma0/var_Sigma0
Sigma0[1, 1] = 1/var_Sigma0

estimator = OmegaEstimatorGaussian(data_scaled[100:200], m, grad_m, mu0, Sigma0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16200/3048436743.py in <module>
#      18 Sigma0[1, 1] = 1/var_Sigma0
#      19
# ---> 20 estimator = OmegaEstimatorGaussian(data_scaled[100:200], m, grad_m, mu0, Sigma0)
#
# NameError: name 'OmegaEstimatorGaussian' is not defined
